# %%
#import pandas
#from time import time
#kdd_data_train = pandas.read_csv("/Users/wandawang/Desktop/NSL_KDD-master/new.KDD.train.csv")
#kdd_data_train.describe()

# %%
import pandas
from time import time
kdd_data_traina= pandas.read_csv("/Users/wandawang/Desktop/NSL_KDD-master/KDD.train.attack2.csv")
kdd_data_traina.head()
labels = kdd_data_traina['outcome']
#outcome column type was changed to numeric in Rstudio 
#kdd_data_traina.describe()

# %%
#kdd_data_trainah= pandas.read_csv("/Users/wandawang/Desktop/NSL_KDD-master/KDD.train.attack.csv")
#outcome column type was kept as factor in Rstudio for kdd_data_trinah
kdd_data_traina['outcome'].value_counts() #works with .astype(float)
#kdd_data_traina['outcome'].value_counts() # graph, types of attacks 4 subcategories too, manual maybe
# Out:
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: outcome, dtype: int64

# %%
num_features = [# didn't recognize "aol" as a column index 
    "duration","src_bytes", 
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate"
]
features = kdd_data_traina[num_features].astype(float) 
features.describe() #features are the continuous features only
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %%
#import pandas
#from time import time
#kdd_data_train1 = pandas.read_csv("/Users/wandawang/Desktop/NSL_KDD-master/kdd_data_train.csv").astype(float)
#kdd_data_train1.describe()

# %%
# dfa = kdd_data_traina.astype(float)
# #features
# type(kdd_data_train1.astype(float))
# df = kdd_data_train1.astype(float)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
kdd_data_traina = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
kdd_data_traina.describe()
#features are scaled
# Out:
#             duration     src_bytes     dst_bytes           land  \
# count  125973.000000  1.259730e+05  1.259730e+05  125973.000000
# mean        0.006692  3.302024e-05  1.509928e-05       0.000198
# std         0.060700  4.253974e-03  3.069818e-03       0.014086
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.000000  3.188489e-08  0.000000e+00       0.000000
# 75%         0.000000  2.000052e-07  3.939120e-07       0.000000
# max         1.000000  1.000000e+00  1.000000e+00       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.007562       0.000037       0.002655           0.000244
# std          0.084510       0.004789       0.027922           0.009048
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %%
#import pandas as pd
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#kdd_data_train1 = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
#kdd_data_train1.describe()

# %%
#kdd_data_train['outcome.response'].value_counts()

# %%
from sklearn.cluster import KMeans
k = 30
km = KMeans(n_clusters = k)
t0 = time()
km.fit(kdd_data_traina) #kdd_data_train1
tt = time()-t0
print "Clustered in {} seconds".format(round(tt,3))
# Out:
# Clustered in 32.437 seconds

# %%
pandas.Series(km.labels_).value_counts()
# Out:
# 2     17586
# 1     17099
# 6     16691
# 13    16189
# 9      8166
# 4      6895
# 27     4318
# 16     3670
# 11     3644
# 10     3409
# 12     2880
# 7      2695
# 28     2002
# 5      1860
# 3      1741
# 21     1710
# 19     1699
# 8      1635
# 14     1546
# 24     1503
# 17     1477
# 18     1161
# 29     1134
# 0      1098
# 26     1082
# 15      898
# 23      884
# 20      727
# 22      428
# 25      146
# dtype: int64

# %%
# labels = kdd_data_traina['outcome'] #duration works but not outcome
label_names = map(
    lambda x: pandas.Series([labels[i] for i in range(len(km.labels_)) if km.labels_[i]==x]), 
    range(k))

# %%
#labels = kdd_data_train1['outcome.response']
#label_names = map(
#    lambda x: pandas.Series([labels[i] for i in range(len(km.labels_)) if km.labels_[i]==x]), 
#    range(k))

# %%
for i in range(k):
    print "Cluster {} labels:".format(i)
    print label_names[i].value_counts()
    print
# Out:
# Cluster 0 labels:
# portsweep    649
# satan        426
# normal        23
# dtype: int64
#
# Cluster 1 labels:
# normal    17099
# dtype: int64
#
# Cluster 2 labels:
# neptune      17555
# portsweep       30
# nmap             1
# dtype: int64
#
# Cluster 3 labels:
# normal       1420
# smurf         170
# satan          60
# pod            58
# nmap           16
# portsweep       7
# teardrop        6
# rootkit         3
# spy             1
# dtype: int64
#
# Cluster 4 labels:
# neptune      6868
# portsweep      17
# normal         10
# dtype: int64
#
# Cluster 5 labels:
# smurf     1000
# normal     635
# satan      170
# nmap        55
# dtype: int64
#
# Cluster 6 labels:
# normal       16265
# back           421
# phf              3
# portsweep        1
# satan            1
# dtype: int64
#
# Cluster 7 labels:
# normal          2618
# guess_passwd      49
# ipsweep           12
# neptune            9
# back               7
# dtype: int64
#
# Cluster 8 labels:
# ...

# %%
km.labels_
# Out:
# array([ 3, 12, 13, ..., 20, 13, 27], dtype=int32)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
print kdd_data_train1[:0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, duration, aol, auth, bgp, courier, csnet_ns, ctf, daytime, discard, domain, domain_u, echo, eco_i, ecr_i, efs, exec, finger, ftp, ftp_data, gopher, harvest, hostnames, http, http_2784, http_443, http_8001, imap4, IRC, iso_tsap, klogin, kshell, ldap, link, login, mtp, name, netbios_dgm, netbios_ns, netbios_ssn, netstat, nnsp, nntp, ntp_u, other, pm_dump, pop_2, pop_3, printer, private, red_i, remote_job, rje, shell, smtp, sql_net, ssh, sunrpc, supdup, systat, telnet, tftp_u, tim_i, time, urh_i, urp_i, uucp, uucp_path, vmnet, whois, X11, Z39_50, icmp, tcp, udp, OTH, REJ, RSTO, RSTOS0, RSTR, S0, S1, S2, S3, SF, SH, src_bytes, dst_bytes, land, wrong_fragment, urgent, hot, num_failed_logins, logged_in, num_compromised, root_shell, su_attempted, num_root, num_file_creations, num_shells, ...]
# Index: []
#
# [0 rows x 124 columns]

# %%
km.cluster_centers_
# Out:
# array([[  2.91522609e-03,   2.50811056e-07,   1.09883030e-07, ...,
#           1.93989071e-03,   5.43697632e-01,   9.90482696e-01],
#        [  1.03853369e-05,   2.29282337e-07,   4.23174215e-06, ...,
#           1.01695906e-03,   9.80935673e-03,   1.83719298e-02],
#        [  2.65048095e-08,   7.17606313e-18,  -2.96630938e-18, ...,
#           9.99431366e-01,   5.52712385e-04,   5.68634141e-04],
#        ...,
#        [  7.65548540e-03,   9.34302098e-05,   1.13096622e-05, ...,
#           9.87711570e-03,   5.62044980e-02,   6.74240668e-03],
#        [  4.07959943e-03,   1.17164569e-04,   2.99729912e-06, ...,
#           3.30169830e-03,   4.94505495e-03,   1.03546454e-02],
#        [  7.11665778e-04,   1.46193535e-06,   2.04144279e-07, ...,
#           6.43738977e-03,   1.94356261e-02,   1.61375661e-02]])
